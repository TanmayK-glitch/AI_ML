# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data = data.iloc[:, 2:]

# %%
data.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 357   41            72000          0
# 286   37            62000          0
# 188   35            72000          0
# 176   35            47000          0
# 235   46            79000          1

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data.drop('Purchased', asix = 1),
                                                    data['Purchased'],
                                                    test_size = 0.3,
                                                    random_state = 0)
X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(data.drop('Purchased', asix = 1),
#       3                                                     data['Purchased'],
#       4                                                     test_size = 0.3,
#       5                                                     random_state = 0)
#       6 X_train.shape, X_test.shape
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'asix'
