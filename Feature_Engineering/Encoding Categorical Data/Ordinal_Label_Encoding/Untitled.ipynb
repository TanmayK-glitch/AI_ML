# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('table.csv')

# %%
data.head(5)
# Out:
#   Customer_ID    Age_Group Education_Level Income_Level Satisfaction_Rating  \
# 0        C001        Young     High School          Low      Very Satisfied
# 1        C002  Middle-Aged      Bachelor's       Medium           Satisfied
# 2        C003       Senior        Master's         High             Neutral
# 3        C004        Young             PhD         High        Dissatisfied
# 4        C005  Middle-Aged     High School          Low   Very Dissatisfied
#
#        City  Gender Product_Rating
# 0  New York    Male              5
# 1    London  Female              4
# 2     Tokyo    Male              3
# 3    Berlin  Female              2
# 4    Mumbai    Male              1

# %%
data.iloc[:, 1:5]
# Out:
#      Age_Group Education_Level Income_Level Satisfaction_Rating
# 0        Young     High School          Low      Very Satisfied
# 1  Middle-Aged      Bachelor's       Medium           Satisfied
# 2       Senior        Master's         High             Neutral
# 3        Young             PhD         High        Dissatisfied
# 4  Middle-Aged     High School          Low   Very Dissatisfied
# 5          ...             ...          ...                 ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data.iloc[:, 1:5], data.iloc[:, -2], test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# %%
X_train.head()
# Out:
#      Age_Group Education_Level Income_Level Satisfaction_Rating
# 4  Middle-Aged     High School          Low   Very Dissatisfied
# 2       Senior        Master's         High             Neutral
# 0        Young     High School          Low      Very Satisfied
# 3        Young             PhD         High        Dissatisfied

# %%
oe = OrdinalEncoder(categories=[["Young", "Middle-Aged", "Senior"],
                                ["High School", "Bachelor's", "Master's", "PhD"],
                                ["Low", "Medium", "High"],
                              ["Very Dissatisfied", "Dissatisfied", "Neutral", "Satisfied", "Very Satisfied"]])

# %%
# ordinal_cols = ['Age_Group', 'Education_Level', 'Income_Level', 'Satisfaction_Rating']

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Young', 'Middle-Aged', 'Senior'],
#                            ['High School', "Bachelor's", "Master's", 'PhD'],
#                            ['Low', 'Medium', 'High'],
#                            ['Very Dissatisfied', 'Dissatisfied', 'Neutral',
#                             'Satisfied', 'Very Satisfied']])

# %%
oe.fit_transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 oe.fit_transform(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
# ...

# %%
X_train = oe.transform(X_train)
X_test = oe.transform(X_test)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 X_train = oe.transform(X_train)
#       2 X_test = oe.transform(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...

# %%
X_train
# Out:
# array([[1., 0., 0., 0.],
#        [2., 2., 2., 2.],
#        [0., 0., 0., 4.],
#        [0., 3., 2., 1.]])
