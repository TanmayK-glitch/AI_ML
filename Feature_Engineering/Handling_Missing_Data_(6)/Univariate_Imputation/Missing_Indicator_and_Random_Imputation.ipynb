# %%
print("Working")
# Out:
# Working

# %%
# Missing Imputation and Random Imputaion
# 1. Random Sample Imputation
    # It means selecting values which are aleady present in that specific column (not any random value), and in it the Distribution and shape is not affected. 
    # This works best for linear models like LogisticRegression and LinearRegression
    # It is bad for Tree Models... as it brings randomness in the DF which tree models cant handle well
    # Crucial Implementation: when you set this model live make sure the model generates same data for a same given value, you can enable this using `random_state`

# 2. Missing Indicator
    # In this you tell the Model that you have faked some values in the DF and to do this you create a new Boolen Column which states if the value is Faked -> True : False

# 3. Automated Parameter Selection
    # Instead of guessing the best imputation stratergy, you automate the selection process.
    # Define a parameter grid: -> Mean vs Median (for numerical data)
                             # -> Most Frequent vs Constant (for categorical data)
    # You pass: these into GridSearchCV
                #Your pipeline
                #The parameter grid
