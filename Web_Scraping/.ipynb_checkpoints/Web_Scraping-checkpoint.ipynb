# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup #this lib is used in web scraping

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/80.0.3987.162 Safari/537.36'
}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1', headers = headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\tTop Companies in\n\t\t\t\t \n\t\t\t\t\tINDIA\n\t\t\t\t\t'

# %%
for i in soup.find_all('h2'):
    print(i.text.strip()) #Used to remove leading and spaces
# Out:
# Companies in India
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Jio
# Axis Bank
# Concentrix Corporation
# Amazon
# iEnergizer
# Reliance Retail
# LTIMindtree
# IBM
# Popular Collections by Industries
# Popular Collections by Cities
# Popular Collections by Roles

# %%
len(soup.find_all('p', class_='rating'))
# Out:
# 0

# %%
len(soup.find_all('a', class_= 'review_count'))
# Out:
# 0

# %%
comapny = soup.find_all('div', class_='company_content_wrapper')
# Out:
# 0
